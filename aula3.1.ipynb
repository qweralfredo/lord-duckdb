# %% [markdown]
# ## 3.1 - Views e CTAs
#
# - Utilizando views para simplificar a fonte do dado
# - Materializando os dados com CTAs

# %% [markdown]
# ## Views
#
# - Para simplificar o carregamento dos dados e criar uma nomenclatura base no seu banco de dados
# - Complexidade das Consultas e/ou funções das consultas
# - Outras fontes de dados
# - Performace ok!

# %%
# !pip install duckdb --quiet
# !pip install jupysql pandas duckdb-engine  --quiet
# %pip install magic_duckdb --upgrade  --quiet
# %load_ext magic_duckdb
# %config SqlMagic.autopandas = True

# %%
# %dql create or replace view vw_movies as  select * from read_csv('data/movie_metadata.csv');
# Out:
# Empty DataFrame
# Columns: [Count]
# Index: []

# %%
# %dql describe select *  from vw_movies;
# Out:
#                   column_name column_type null   key default extra
# 0                       color     VARCHAR  YES  None    None  None
# 1               director_name     VARCHAR  YES  None    None  None
# 2      num_critic_for_reviews      BIGINT  YES  None    None  None
# 3                    duration      BIGINT  YES  None    None  None
# 4     director_facebook_likes      BIGINT  YES  None    None  None
# 5      actor_3_facebook_likes      BIGINT  YES  None    None  None
# 6                actor_2_name     VARCHAR  YES  None    None  None
# 7      actor_1_facebook_likes      BIGINT  YES  None    None  None
# 8                       gross      BIGINT  YES  None    None  None
# 9                      genres     VARCHAR  YES  None    None  None
# 10               actor_1_name     VARCHAR  YES  None    None  None
# 11                movie_title     VARCHAR  YES  None    None  None
# 12            num_voted_users      BIGINT  YES  None    None  None
# 13  cast_total_facebook_likes      BIGINT  YES  None    None  None
# 14               actor_3_name     VARCHAR  YES  None    None  None
# 15       facenumber_in_poster      BIGINT  YES  None    None  None
# 16              plot_keywords     VARCHAR  YES  None    None  None
# 17            movie_imdb_link     VARCHAR  YES  None    None  None
# 18       num_user_for_reviews      BIGINT  YES  None    None  None
# 19                   language     VARCHAR  YES  None    None  None
# 20                    country     VARCHAR  YES  None    None  None
# 21             content_rating     VARCHAR  YES  None    None  None
# 22                     budget      BIGINT  YES  None    None  None
# 23                 title_year      BIGINT  YES  None    None  None
# 24     actor_2_facebook_likes      BIGINT  YES  None    None  None
# 25                 imdb_score      DOUBLE  YES  None    None  None
# 26               aspect_ratio      DOUBLE  YES  None    None  None
# 27       movie_facebook_likes      BIGINT  YES  None    None  None

# %%
# %dql select title_year, count(*) as total from vw_movies group by title_year order by total desc limit 10;
# Out:
#    title_year  total
# 0        2009    260
# 1        2014    252
# 2        2006    239
# 3        2013    237
# 4        2010    230
# 5        2015    226
# 6        2011    225
# 7        2008    225
# 8        2012    221
# 9        2005    221

# %% [markdown]
# ## CTAs
#
# - Performace ruim na view (ou query)
# - Query muito complexa
# - Query muito lenta
# - Query muito pesada
# - Necessidade de otimização (indices, etc)
# - Dimensões e Fatos
# - Arquitetura Medalha (bronze, prata,ouro)

# %%
# %dql create or replace table cta_total_by_year as select title_year, count(*) as total from vw_movies group by title_year;
# Out:
#    Count
# 0     92

# %%
# %dql select * from cta_total_by_year;
# Out:
#     title_year  total
# 0       2006.0    239
# 1       2008.0    225
# 2       1977.0     16
# 3       1965.0      8
# 4       1975.0      6
# ..         ...    ...
# 87      1950.0      1
# 88      1948.0      3
# 89      1944.0      1
# 90      1949.0      2
# 91      1941.0      1
#
# [92 rows x 2 columns]
